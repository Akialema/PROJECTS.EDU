# %% [markdown]
# Добавлю в самое начало ссылку на [список всех HTML](https://html5book.ru/html-tags/) тэгов, которые пашут в даунмарке.)))
#
# # Header1
# или
# <h1>Header1</h1>
# (в первом случае всё, что ниже может быть свёрнуто через галку слева, а во втором - нет)
#
# ## Header2
# ### Header3
#
# ---
#
# <span style="display: flex; float: left; align-items: center; justify-content: center; font-size: 16px; color: #2e765e; width: 30px; height: 30px; border: 2px solid #2e765e; border-radius: 50%; margin: 0px 20px 20px;">100</span> Кружочек. Тут обязательно должен быть текст. <br> Причем в пару строк, чтобы ничего не съезжало, за это отвечает параметр float: left;
#
# ---
#
# <span style="display: inline-block; float: right; text-align: center; line-height: 30px; font-size: 16px; color: #fff; width: 30px; height: 30px; border: 2px solid #fff; border-radius: 50%; margin: -5px 20px 20px;">0k</span>Задача - создать такую модель.
#
# ---
#
# <font color='red'>Красный текст</font> (устаревшее)
# <center><ins><p style='color:blue'>Синий текст</p></ins></center>
#
# > Где ```<center>``` - это текст по центру
# > ```<ins>``` - подчёркивание
# > Так же подчёркивание получится при ```<u></u>```
#
# <span style='color:cyan'>Забыл самое главное</span> - <span style='color:lightgreen'>изменение цвета текста</span>. <span style='color:gold'>А то <span style='color:blue'>синий текст</span> выше какой-то не наглядный</span>.
#
# ---
#
# <mark> хуй, говно и муравей </mark>
#
# ---
#
# <div style="background: #e0fff3; color: #000; border-left: 6px solid green; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# <span style="font-weight: bold; color: #2e675e;">Линейная взаимосвязь</span> — вид связи между признаками, в котором изменение одного признака $x_{1}$ всегда приводит к изменению другого признака $x_{2}$ на величину, пропорциональную изменению $x_{1}$, в соответствии с правилом: $x_{2}$ = $ax_{1}$ + $b$ (уравнение прямой), где $a$ и $b$ — некоторые коэффициенты.
# </div>
#
# ---
#
# <div style="background: #228b22; color: #000; border-left: 6px solid darkgreen; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# Ещё 1 вариант изменения бэкграунда текста, тут еще можно цвет текста `менять`
# </div>
#
# ---
#
# <div style="border: 3px solid yellow; color: gold; border-radius: 15px / 50px; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# Нужно просто поменять текст внутри ДИВа. За цвет текста отвечает color. А за округление границ - border-radius
# </div>
#
# ---
#
# <div style="border: 3px dotted cyan; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# Сохранение и восстановление работает в пару строк. В результате мы можем приводить достаточно сложные операции к простому виду.
# </div>
#
# ---
#
# <div style="border: 3px outset lightgreen; background: lightgray; color: black; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# Дополнительная литература про ООП:
#
# Если хотите подробнее разобраться с ООП, почитайте [Erric Matthes](https://www.amazon.com/Python-Crash-Course-Hands-Project-Based/dp/1593276036) (для начинающих) и [Dusty Phillips](https://www.amazon.com/Python-3-Object-Oriented-Programming/dp/1849511268) OOP in Python 3 (руководство с практическими примерами на все случаи жизни).
# </div>
#
# ---
#
# <div style="border: 3px solid gray; background: lightgray; color: black; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# Если вы захотите углубиться в очистку данных и статистические методы, то вашему вниманию предлагается дополнительная литература:
#
# * Статья «[Подготовка данных в Data Science-проекте: рецепты для молодых хозяек](https://habr.com/ru/articles/470650/)» (Хабр). Автор описывает общие подходы к очистке данных и какое место очистка занимает в бизнес-проекте.
#
# * [Замечательная книга Абдрахманова](https://itfy.org/threads/kniga-o-biblioteke-pandas-pandas-rabota-s-dannymi-abdraxmanov-m-i.1262/), которую вы можете использовать как справочник при работе с pandas.
#
# * Тем, кто хочет познакомиться с высокоуровневыми методами поиска выбросов, которые мы не рассмотрели в модуле, рекомендуем эту [статью по Anomaly Detection](https://alexanderdyakonov.wordpress.com/2017/04/19/%D0%BF%D0%BE%D0%B8%D1%81%D0%BA-%D0%B0%D0%BD%D0%BE%D0%BC%D0%B0%D0%BB%D0%B8%D0%B9-anomaly-detection/).
#
# * [Практическая статистика для специалистов DS](https://www.litres.ru/book/piter-brus-32090127/prakticheskaya-statistika-dlya-specialistov-data-scien-67725521/)
#
# * [Статистика и котики](https://www.litres.ru/book/vladimir-savelev-10569666/statistika-i-kotiki-28731109/chitat-onlayn/)
#
# <div style="background: #e0fff3; border-radius: 15px / 50px; box-shadow: 10px 10px 5px darkgray; color: #000; border-left: 8px solid darkgreen; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# [Прикладной анализ текстовых данных на Python. Машинное обучение и создание приложений обработки естественного языка.](https://habr.com/ru/companies/piter/articles/444384/)
# Векторизация (библиотеки): [gensim](https://pypi.org/project/gensim/) Doc2Vec
# </div>
# <br>
# <div style="background: #e0fff3; border-radius: 15px 50px 30px 5px; box-shadow: 10px 10px 5px darkgray; color: #fff; border-left: 8px solid darkgreen; text-align:left; vertical-align: middle; padding:15px 20px 3px; width: auto;">
#
# [Box shadow](https://www.w3schools.com/css/css3_shadows_box.asp) & [Border radius](https://www.w3schools.com/css/css3_borders.asp)
# </div>
# <br>
# </div>
#
# ---
#
# збс статья про [border](https://itchief.ru/html-and-css/border)
#
# ---
#
# <span style='background: green'>
# Если после создания оглавления начинает съезжать переход при клике, нужно отмотать свой код в самое начало, сохранить и закрыть-открыть .ipynb файл.<br>
# Или если изменения не проводились, то просто отмотать в начало и закрыть-открыть. И оглавление будет работать чётко.
# </span>
#
# ---
#
# Если вдруг нужна красивая таблица в маркдауне через хтмл код.
#
# <table style="width: 80%; padding: 0.2em; border-collapse: collapse; margin: 0px auto; border: 1px solid #b0b0b0;">
# <tbody>
# <tr>
# <td style="width: 50%; text-align: center; vertical-align: middle; background-color: #10564f; border: 1px solid #b0b0b0; padding: 0.2em;"><span style="color: #ffffff;">Сила связи</span></td>
# <td style="width: 50%; text-align: center; vertical-align: middle; background-color: #10564f; border: 1px solid #b0b0b0; padding: 0.2em;"><span style="color: #ffffff;">Значение коэффициента корреляции</span></td>
# </tr>
# <tr>
# <td style="width: 50%; text-align: left; border: 1px solid #b0b0b0; padding: 0.2em;">Отсутствие связи или очень слабая связь</td>
# <td style="width: 50%; text-align: center; border: 1px solid #b0b0b0; padding: 0.2em;">0…+/- 0.3</td>
# </tr>
# <tr>
# <td style="width: 50%; text-align: left; border: 1px solid #b0b0b0; padding: 0.2em;">Слабая связь</td>
# <td style="width: 50%; text-align: center; border: 1px solid #b0b0b0; padding: 0.2em;">+/- 0.3…+/- 0.5</td>
# </tr>
# <tr>
# <td style="width: 50%; text-align: left; border: 1px solid #b0b0b0; padding: 0.2em;">Средняя связь</td>
# <td style="width: 50%; text-align: center; border: 1px solid #b0b0b0; padding: 0.2em;">+/- 0.5…+/- 0.7</td>
# </tr>
# <tr>
# <td style="width: 50%; text-align: left; border: 1px solid #b0b0b0; padding: 0.2em;">Сильная связь</td>
# <td style="width: 50%; text-align: center; border: 1px solid #b0b0b0; padding: 0.2em;">+/- 0.7…+/- 0.9</td>
# </tr>
# <tr>
# <td style="width: 50%; text-align: left; border: 1px solid #b0b0b0; padding: 0.2em;">Очень сильная или абсолютная связь</td>
# <td style="width: 50%; text-align: center; border: 1px solid #b0b0b0; padding: 0.2em;">+/- 0.9…+/-1</td>
# </tr>
# </tbody>
# </table>
#
# ---
#
# *fdfdfdfd*
#
# **hdhdhdhd**
#
# ~~kdkdkdkd~~
#
# <b>bold text<b>
#
# <i>italic<i>
# * jfbdhvd
# * sfndv
# * kfndf
# 1. jdnjsncs
# 2. fdcdfd
# 3. dfcdf
#
# [prnhub](https://pornhub.com)
#
# ![pic](https://raw.githubusercontent.com/Akialema/Akialema/main/bannerimage.jpg)
#
#
# <img src='2.Project-2:HH_sql_jobs_analytics/proj_pics/general_scheme.png' width='50%' height='50%' style='display:block; margin:auto;'>
#
# $$ x = y^2 $$
# $$ язык\ латех\ |\ латеховские\ формулы:\ (a+b)^2 = a^2 + 2ab + b^2\ \\
# c =\ ^3\sqrt{27} $$
# $$ x_{1}^2 + x_{2}^2 $$
# P.s. обращу внимание на перенос строки в латеховой формуле. \\ Два обратных слэша.
#
# И чтобы было выровнено по левому краю, используем `\hspace{100em}` в конце (на кагле не работает), например:
# $$ \mu\ +\ 3\sigma\hspace{100em} $$
#
# Чтобы <font color=gradient>LaTex</font> формула была в одной строке с обычным тексом - нужно использовать 1 доллар, вместо двух:
# $\sqrt{27}$ или: $\mu\ +\ 3\sigma$, или: $(a+b)^2 = a^2 + 2ab + b^2$, или: $x_{1}^2 + x_{2}^2$, или дробь $\frac{1}{2}$ и т.д.
#
#
# Документация по [библиотеке KaTeX](http://sepetov.ru/2016/04/20/katex-%D0%B1%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0-%D0%B4%D0%BB%D1%8F-%D0%BC%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D1%85-%D1%84%D0%BE%D1%80%D0%BC/) и по [языку LaTeX](https://en.wikibooks.org/wiki/LaTeX/Mathematics)
